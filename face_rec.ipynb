# %% [markdown]
# <a href="https://colab.research.google.com/github/DEVANSH-JINDAL/Machine-Learning/blob/master/face_rec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cmake dlib face_recognition opencv-python
# Out:
# ...
#      |████████████████████████████████| 100.2MB 101kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566176 sha256=c88282d6ee1450c81ad3b103cd5a39ac329a1a6cec49f3a656a55a6874862d72
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
from google.colab import drive
drive.mount('/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive/

# %%
# %cd /gdrive/My Drive/face_recog
# Out:
# /gdrive/My Drive/face_recog

# %%
# %ls
# Out:
# abc.jpg   devansh.jpg  faces/   sher.jpg  we3.jpg
# dev2.jpg  dev_s.jpg    rec.jpg  test/

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread("sher.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x378 at 0x7F3CB49AFCF8>

# %%
cv2.imwrite("abc.jpg",image)
# Out:
# True

# %%
ls
# Out:
# abc.jpg   devansh.jpg  faces/   sher.jpg  we3.jpg
# dev2.jpg  dev_s.jpg    rec.jpg  test/

# %%
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
HSV=cv2.cvtColor(image,cv2.COLOR_BGR2HLS)

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=500x378 at 0x7F3CB41377F0>

# %%
cv2_imshow(HSV)
# Out:
# <PIL.Image.Image image mode=RGB size=500x378 at 0x7F3CB4137518>

# %%
img=cv2.resize(image,(100,100))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F3CB4137B70>

# %%
rows,cols=image.shape[:2]
m=cv2.getRotationMatrix2D((cols/2,rows/2),150,1)

# %%
dst =cv2.warpAffine(image,m,(cols,rows))

# %%
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=500x378 at 0x7F3CB41378D0>

# %%
import numpy as np

# %%
M=np.float32([[1,0,-100],[0,1,-100]])

# %%
dst=cv2.warpAffine(image,M,(cols,rows))

# %%
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=500x378 at 0x7F3CB4137EF0>

# %%
edge=cv2.Canny(image,100,500)
cv2_imshow(edge)
# Out:
# <PIL.Image.Image image mode=L size=500x378 at 0x7F3CB4137DD8>

# %%
edge=cv2.Canny(image,100,400)
cv2_imshow(edge)
# Out:
# <PIL.Image.Image image mode=L size=500x378 at 0x7F3CB4137908>

# %%
edge=cv2.Canny(image,10,1000)
cv2_imshow(edge)
# Out:
# <PIL.Image.Image image mode=L size=500x378 at 0x7F3CB41379B0>

# %%
import face_recognition

# %%
image=cv2.imread("faces/obama.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=425x531 at 0x7F3C7F9F3978>

# %%
img=face_recognition.load_image_file("faces/obama.jpg")

# %%
loc =face_recognition.face_locations(image)

# %%
loc
# Out:
# [(56, 259, 163, 151)]

# %%
cv2.rectangle(image,(151,56),(259,163),(255,0,0),2)
cv2.putText(image,"Obama",(151,66),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),2)
# Out:
# array([[[ 25,  29,  88],
#         [ 20,  24,  82],
#         [ 16,  24,  77],
#         ...,
#         [ 48,  53, 138],
#         [ 62,  67, 158],
#         [ 84,  86, 186]],
#
#        [[ 25,  29,  88],
#         [ 20,  24,  82],
#         [ 16,  24,  77],
#         ...,
#         [ 48,  53, 138],
#         [ 62,  67, 158],
#         [ 83,  85, 185]],
#
#        [[ 25,  29,  88],
#         [ 20,  24,  82],
#         [ 16,  23,  78],
#         ...,
#         [ 49,  54, 139],
#         [ 63,  68, 159],
#         [ 83,  85, 185]],
#
#        ...,
#
#        [[ 23,  65, 112],
#         [ 22,  64, 111],
#         [ 22,  62, 110],
#         ...,
#         [ 40,  72, 113],
#         [ 40,  72, 113],
#         [ 31,  63, 104]],
#
#        [[ 37,  84, 135],
#         [ 36,  83, 134],
#         [ 37,  82, 133],
#         ...,
#         [ 28,  66, 108],
#         [ 28,  66, 108],
#         [ 23,  58, 101]],
#
#        [[ 32,  79, 130],
#         [ 31,  78, 129],
#         [ 32,  77, 128],
# ...

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=425x531 at 0x7F3C7F9F3D68>

# %%
features=face_recognition.face_landmarks(img)

# %%
features
# Out:
# [{'bottom_lip': [(236, 135),
#    (228, 146),
#    (218, 152),
#    (210, 153),
#    (202, 153),
#    (192, 148),
#    (184, 137),
#    (186, 138),
#    (203, 146),
#    (210, 147),
#    (218, 146),
#    (233, 136)],
#   'chin': [(158, 94),
#    (159, 107),
#    (160, 122),
#    (163, 135),
#    (168, 149),
#    (176, 161),
#    (185, 172),
#    (197, 180),
#    (210, 182),
#    (223, 179),
#    (234, 170),
#    (244, 158),
#    (252, 147),
#    (257, 134),
#    (259, 120),
#    (260, 107),
#    (261, 94)],
#   'left_eye': [(180, 93),
#    (185, 90),
#    (191, 89),
#    (197, 92),
#    (191, 93),
#    (185, 93)],
#   'left_eyebrow': [(169, 89), (174, 82), (183, 78), (193, 78), (203, 81)],
#   'nose_bridge': [(211, 90), (211, 98), (211, 107), (211, 116)],
#   'nose_tip': [(198, 121), (204, 123), (210, 124), (217, 122), (223, 121)],
#   'right_eye': [(224, 92),
#    (230, 89),
#    (236, 89),
#    (241, 92),
#    (236, 93),
#    (230, 93)],
# ...

# %%
known=face_recognition.load_image_file("faces/obama.jpg")
unknown=face_recognition.load_image_file("faces/papu.jpg")

known_en=face_recognition.face_encodings(known)[0]
unknown_en=face_recognition.face_encodings(unknown)[0]

# %%
known_en
# Out:
# array([-0.08755367,  0.10773158,  0.01999612, -0.05550655,  0.00843576,
#        -0.02576596, -0.09307694, -0.09897819,  0.18704212, -0.10008624,
#         0.2465817 ,  0.0873201 , -0.19639616, -0.15189514,  0.05653508,
#         0.11262398, -0.17974773, -0.07726258, -0.09125439, -0.10767139,
#         0.03024916, -0.00941965,  0.09719743,  0.04354378, -0.1363807 ,
#        -0.33909184, -0.0702142 , -0.18656197, -0.00325655, -0.0990543 ,
#        -0.09149966,  0.00915543, -0.17392004, -0.11894087,  0.02451811,
#        -0.01649242,  0.01257181,  0.00997087,  0.20941307,  0.03357464,
#        -0.12165179,  0.08693286,  0.01815106,  0.21104324,  0.29289901,
#         0.08263063, -0.00823481, -0.09162937,  0.11692937, -0.21978229,
#         0.07514725,  0.15613881,  0.08962798,  0.03603175,  0.08901371,
#        -0.18280578, -0.00181064,  0.08707274, -0.15427923,  0.01438087,
#         0.01167026, -0.08415168, -0.04811291,  0.04439955,  0.20771673,
# ...

# %%
unknown_en
# Out:
# array([-0.06864673,  0.06722605,  0.015582  , -0.08958156, -0.0696795 ,
#        -0.00911151, -0.12950517, -0.07452928,  0.11017897, -0.0631922 ,
#         0.11997763, -0.04898041, -0.19249286, -0.00532659, -0.00044233,
#         0.0730168 , -0.16049157, -0.07732058, -0.04360311, -0.10407885,
#         0.04241116,  0.05174489, -0.03478518,  0.03085246, -0.12283649,
#        -0.22777498, -0.16042407, -0.13294505,  0.07755093, -0.00331602,
#        -0.01289585, -0.01152987, -0.17361301, -0.10159375,  0.08538222,
#         0.09549455, -0.06666036, -0.03069276,  0.16938433, -0.00736896,
#        -0.05858124,  0.05711769,  0.09171961,  0.27811313,  0.16536058,
#         0.0403823 ,  0.03587046, -0.01459797,  0.16769886, -0.21385249,
#         0.18406399,  0.12202238,  0.18424651,  0.13205451,  0.20124309,
#        -0.2412046 ,  0.07018484,  0.21364334, -0.14488755,  0.13561749,
#         0.04680958,  0.00654547,  0.00107809,  0.01418527,  0.18428606,
# ...

# %%
results=face_recognition.compare_faces([known_en],unknown_en)

# %%
results
# Out:
# [False]

# %%
distance=face_recognition.face_distance([known_en],unknown_en)

# %%
distance
# Out:
# array([0.80303502])
