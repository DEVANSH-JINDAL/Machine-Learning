# %% [markdown]
# <a href="https://colab.research.google.com/github/DEVANSH-JINDAL/Machine-Learning/blob/master/face_compare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cmake dlib face_recognition opencv-python
# Out:
# ...
#      |████████████████████████████████| 100.2MB 105kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566176 sha256=d2decad82aeeb819e10d9ac983a9636e65ee07d35326a0315853421ad7257362
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
from google.colab import drive
drive.mount('/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive/

# %%
# %cd /gdrive/My Drive/face_recog
# Out:
# /gdrive/My Drive/face_recog

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
import face_recognition

# %%
image=cv2.imread("faces/test4.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=620x464 at 0x7FAC7668E8D0>

# %%
img=face_recognition.load_image_file("faces/test4.jpg")

# %%
loc=face_recognition.face_locations(image)

# %%
loc
# Out:
# [(47, 337, 121, 262), (106, 215, 196, 126), (118, 463, 170, 412)]

# %%
F1=cv2.rectangle(image,(266,53),(328,115),(255,0,0),2) # TRBL
cv2.putText(image,"Trump",(269,50),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),2)
F2=cv2.rectangle(image,(129,113),(204,188),(255,0,0),2)
cv2.putText(image,"Modi",(126,100),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),2)
#cv2.rectangle(image,(415,117),(460,162),(255,0,0),2)
# Out:
# array([[[43, 44, 48],
#         [43, 44, 48],
#         [44, 45, 49],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]],
#
#        [[43, 44, 48],
#         [43, 44, 48],
#         [44, 45, 49],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]],
#
#        [[43, 44, 48],
#         [43, 44, 48],
#         [44, 45, 49],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]],
#
#        ...,
#
#        [[41, 42, 46],
#         [42, 43, 47],
#         [43, 44, 48],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]],
#
#        [[43, 44, 48],
#         [42, 43, 47],
#         [42, 43, 47],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]],
#
#        [[44, 45, 49],
#         [43, 44, 48],
#         [42, 43, 47],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]]], dtype=uint8)

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=620x464 at 0x7FAC7668E978>

# %%
# Out:
# array([[[43, 44, 48],
#         [43, 44, 48],
#         [44, 45, 49],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]],
#
#        [[43, 44, 48],
#         [43, 44, 48],
#         [44, 45, 49],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]],
#
#        [[43, 44, 48],
#         [43, 44, 48],
#         [44, 45, 49],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]],
#
#        ...,
#
#        [[41, 42, 46],
#         [42, 43, 47],
#         [43, 44, 48],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]],
#
#        [[43, 44, 48],
#         [42, 43, 47],
#         [42, 43, 47],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]],
#
#        [[44, 45, 49],
#         [43, 44, 48],
#         [42, 43, 47],
#         ...,
#         [32, 36, 37],
#         [32, 36, 37],
#         [32, 36, 37]]], dtype=uint8)

# %%
known=face_recognition.load_image_file("faces/test4.jpg")
unknown=face_recognition.load_image_file("faces/test3.jpg")
known_en=face_recognition.face_encodings(known)[1]
unknown_en=face_recognition.face_encodings(unknown)[1]

# %%
known_en
# Out:
# array([-1.33141428e-01,  1.39034940e-02,  3.19970772e-02, -8.51420686e-02,
#        -4.39394787e-02, -1.20227724e-01,  2.53552664e-02, -6.94582462e-02,
#         1.48383319e-01,  1.16480663e-02,  1.20305225e-01, -7.14619085e-03,
#        -2.00229943e-01, -6.60372153e-02,  3.99456173e-03,  5.32382056e-02,
#        -1.53593138e-01, -7.81980902e-02, -6.44404292e-02, -1.46107271e-01,
#         1.24504566e-02,  3.92502174e-02,  6.82783723e-02,  2.24978141e-02,
#        -9.51574296e-02, -2.89747477e-01, -1.05116099e-01, -1.66797981e-01,
#        -3.63673270e-03, -4.21559438e-02,  9.77430642e-02,  5.23275509e-02,
#        -2.15135068e-01, -7.92825371e-02, -3.52071226e-03,  6.94097504e-02,
#        -8.08125660e-02, -7.94192851e-02,  1.77436620e-01,  1.37772970e-02,
#        -8.25012177e-02,  2.35653874e-02,  6.59156963e-03,  1.96750358e-01,
#         2.26016819e-01,  6.56171795e-03, -9.30591486e-03, -3.72283310e-02,
# ...

# %%
unknown_en
# Out:
# array([-1.29748940e-01,  3.45834121e-02,  8.52813199e-03, -6.35296851e-02,
#        -1.03256963e-02, -1.16928071e-01,  1.80876609e-02, -7.10414201e-02,
#         1.46127328e-01,  1.22917676e-02,  1.40988067e-01, -1.79770663e-02,
#        -2.19127253e-01, -8.96881968e-02, -2.80919261e-02,  1.82713568e-02,
#        -1.21048182e-01, -6.69434220e-02, -1.05968818e-01, -1.03246450e-01,
#         4.78101298e-02,  1.76528282e-03,  1.45407185e-01,  5.60101122e-03,
#        -7.69342706e-02, -3.64304602e-01, -1.09897025e-01, -1.68761045e-01,
#         5.77856600e-02, -2.31991187e-02,  1.58620328e-02,  1.01097235e-02,
#        -1.98342040e-01, -9.49322432e-02, -2.57298425e-02,  3.10599674e-02,
#        -3.04008136e-04, -3.45572457e-02,  1.88180849e-01,  4.65152785e-03,
#        -1.34420142e-01,  1.31141227e-02,  3.45911346e-02,  2.02067584e-01,
#         2.07103252e-01,  1.30662322e-02,  7.65357912e-03, -5.63318431e-02,
# ...

# %%
result=face_recognition.compare_faces([known_en],unknown_en)

# %%
result
# Out:
# [True]
